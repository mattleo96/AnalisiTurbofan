# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from keras.layers import LSTM,Dropout,GRU,MaxPooling1D,Flatten,concatenate
from keras.models import Sequential
from keras.layers import Dense,Concatenate,Bidirectional
from keras.layers.convolutional import Conv1D
import tensorflow as tf
from keras.utils.vis_utils import model_to_dot
from keras.layers import RepeatVector
from keras.layers import TimeDistributed,Activation
from sklearn.preprocessing import MinMaxScaler
from keras import Input,Model

FD1_train = pd.read_csv("train_FD001.txt",delimiter=" ",header = None)
FD1_test = pd.read_csv("test_FD001.txt",delimiter=" ",header = None)
RUL_file=pd.read_csv("RUL_FD001.txt",header = None)

FD1_test=FD1_test.drop([26, 27], axis = 1)
columns = {0:'unit_number',1:'time_in_cycles',2:'opSetting1',3:'opSetting2',4:'opSetting3',5:'sensor1',6:'sensor2',
           7:'sensor3',8:'sensor4',9:'sensor5',10:'sensor6',11:'sensor7',12:'sensor8',13:'sensor9',14:'sensor10',
           15:'sensor11',16:'sensor12',17:'sensor13',18:'sensor14',19:'sensor15',20:'sensor16',
           21:'sensor17',22:'sensor18',23:'sensor19',24:'sensor20',25:'sensor21'}
FD1_test.columns=columns
FD1_test = FD1_test.rename(columns=columns)
FD1_test=FD1_test.drop(columns = ['opSetting1','opSetting2','opSetting3','sensor1','sensor5','sensor6','sensor10','sensor16','sensor18','sensor19'], axis =1)



FD1_train=FD1_train.drop([26, 27], axis = 1)
columns = {0:'unit_number',1:'time_in_cycles',2:'opSetting1',3:'opSetting2',4:'opSetting3',5:'sensor1',6:'sensor2',
           7:'sensor3',8:'sensor4',9:'sensor5',10:'sensor6',11:'sensor7',12:'sensor8',13:'sensor9',14:'sensor10',
           15:'sensor11',16:'sensor12',17:'sensor13',18:'sensor14',19:'sensor15',20:'sensor16',
           21:'sensor17',22:'sensor18',23:'sensor19',24:'sensor20',25:'sensor21'}
FD1_train = FD1_train.rename(columns=columns)
FD1_train=FD1_train.drop(columns = ['opSetting1','opSetting2','opSetting3','sensor1','sensor5','sensor6','sensor10','sensor16','sensor18','sensor19'], axis =1)

# calcolo RUL
def Calcolo_RUL(df): 
    df_copy=df.copy()
    gruppo=df_copy.groupby('unit_number')['time_in_cycles'].max().reset_index()
    gruppo.columns = ['unit_number','max_cycles_fu']
    df_copy = df_copy.merge(gruppo, on=['unit_number'], how='left')
    df['RUL'] = df_copy['max_cycles_fu'] - df_copy['time_in_cycles']
    return df
Calcolo_RUL(FD1_train)
#normalizzazione train test
cols_normalize = FD1_train.columns.difference( #non considero unit_number,time_in_cycles,RUL per normalizzazione
    ['unit_number', 'time_in_cycles', 'RUL'])  

min_max_scaler = MinMaxScaler()

norm_train_df = pd.DataFrame(min_max_scaler.fit_transform(FD1_train[cols_normalize]),
                             columns=cols_normalize,
                             index=FD1_train.index)

join_df = FD1_train[FD1_train.columns.difference(cols_normalize)].join(norm_train_df)
FD1_train = join_df.reindex(columns=FD1_train.columns)

cols_normalizetest = FD1_test.columns.difference(  #non considero unit_number,time_in_cyclesper normalizzazione
    ['unit_number', 'time_in_cycles'])  

norm_train_df_test = pd.DataFrame(min_max_scaler.transform(FD1_test[cols_normalizetest]),
                             columns=cols_normalizetest,
                             index=FD1_test.index)

join_df = FD1_test[FD1_test.columns.difference(cols_normalizetest)].join(norm_train_df_test)
FD1_test = join_df.reindex(columns=FD1_test.columns)
FD1_test=FD1_test.drop(columns = ['time_in_cycles'], axis =1)
data_cols= FD1_test.columns
##
## reshape dati test
def prepare_test_data(df):
    data_list = []
    for unit_number in df.unit_number.unique():
        unit = df[df.unit_number == unit_number]
        data_list.append(np.array(unit[data_cols])[-31:, :])
    return np.stack(data_list)
FD1_test=prepare_test_data(FD1_test)
FD1_test=FD1_test[:,:,1:]


## upper bound per RUL
rul_clip_limit = 120
FD1_train=FD1_train.clip(upper=rul_clip_limit)

FD1_c=FD1_train.copy()
FD1_train = FD1_train.drop(['RUL','time_in_cycles'], axis=1)
## reshape dati di train
def gen_sequence(id_df, seq_length, seq_cols):
    data_array = id_df[seq_cols].values
    num_elements = data_array.shape[0]
    for start, stop in zip(range(0, num_elements-seq_length), range(seq_length, num_elements)):
        yield data_array[start:stop, :]

seq_gen = (list(gen_sequence(FD1_train[FD1_train['unit_number']==unit_number],31, FD1_train.columns))
           for unit_number in FD1_train['unit_number'].unique())

seq_array = np.concatenate(list(seq_gen)).astype(np.float32)


seq_array=seq_array[:,:,1:] #elimino unit_number dal train
print(seq_array.shape) # dimensione dei dati di train

def gen_labels(id_df, seq_length, label):
    data_array = id_df[label].values
    num_elements = data_array.shape[0]
    return data_array[seq_length:num_elements, :]

label_gen = [gen_labels(FD1_c[FD1_c['unit_number']==id], 31, ['RUL'])
             for id in FD1_c['unit_number'].unique()]
label_array = np.concatenate(label_gen).astype(np.float32)

model= Sequential()
model.add(Conv1D(128,1,padding='same',activation='relu'))
#model.add(Dropout(0.55))
model.add(Conv1D(64,1,padding='same',activation='relu'))
#model.add(Dropout(0.55))
model.add(Conv1D(12,1,padding='same',activation='relu'))
#model.add(Dropout(0.55))
model.add(LSTM(128, input_shape=(31, 14), return_sequences=True))
model.add(Dropout(0.55))
model.add(LSTM(64, input_shape=(31, 14), return_sequences=True))
model.add(Dropout(0.55))
model.add(LSTM(22, input_shape=(31, 14), return_sequences=True))
model.add(Dropout(0.55))
model.add(Bidirectional(LSTM(256, input_shape=(31, 14), return_sequences=True)))
model.add(Dropout(0.55))
model.add(Bidirectional(LSTM(512, input_shape=(31, 14), return_sequences=False)))
model.add(Flatten())
model.add(Dense(1, activation="relu"))

model.compile(loss='mean_squared_error', optimizer='adam',metrics = [tf.keras.metrics.RootMeanSquaredError()])
model.fit(seq_array,label_array ,batch_size=200,epochs=100,verbose=1,validation_split=0.05)
y_pred= model.predict(FD1_test)
from sklearn.metrics import mean_squared_error
from math import sqrt
RUL_file=pd.read_csv("RUL_FD001.txt",header = None)
print(sqrt(mean_squared_error(RUL_file, y_pred)))
print(y_pred)
print((mean_squared_error(RUL_file, y_pred)))
# Out:
# (17531, 31, 14)
# Epoch 1/100
# 84/84 [==============================] - 26s 103ms/step - loss: 3583.9716 - root_mean_squared_error: 69.1319 - val_loss: 1612.0566 - val_root_mean_squared_error: 48.2008
# Epoch 2/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1620.7681 - root_mean_squared_error: 46.7792 - val_loss: 1611.9518 - val_root_mean_squared_error: 44.3391
# Epoch 3/100
# 84/84 [==============================] - 5s 59ms/step - loss: 1611.7624 - root_mean_squared_error: 43.8998 - val_loss: 1612.7673 - val_root_mean_squared_error: 42.9945
# Epoch 4/100
# 84/84 [==============================] - 5s 59ms/step - loss: 1615.2146 - root_mean_squared_error: 42.7833 - val_loss: 1612.6980 - val_root_mean_squared_error: 42.3057
# Epoch 5/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1610.2325 - root_mean_squared_error: 42.1794 - val_loss: 1612.4092 - val_root_mean_squared_error: 41.8883
# Epoch 6/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1627.3524 - root_mean_squared_error: 41.8170 - val_loss: 1612.4513 - val_root_mean_squared_error: 41.6093
# Epoch 7/100
# 84/84 [==============================] - 5s 59ms/step - loss: 1619.4325 - root_mean_squared_error: 41.5579 - val_loss: 1612.1464 - val_root_mean_squared_error: 41.4103
# Epoch 8/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1627.0277 - root_mean_squared_error: 41.3730 - val_loss: 1612.0100 - val_root_mean_squared_error: 41.2588
# Epoch 9/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1608.0025 - root_mean_squared_error: 41.2240 - val_loss: 1612.0754 - val_root_mean_squared_error: 41.1419
# Epoch 10/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1610.4358 - root_mean_squared_error: 41.1149 - val_loss: 1612.1979 - val_root_mean_squared_error: 41.0475
# Epoch 11/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1607.8950 - root_mean_squared_error: 41.0252 - val_loss: 1612.4446 - val_root_mean_squared_error: 40.9699
# Epoch 12/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1603.5111 - root_mean_squared_error: 40.9499 - val_loss: 1612.4561 - val_root_mean_squared_error: 40.9063
# Epoch 13/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1610.4771 - root_mean_squared_error: 40.8912 - val_loss: 1611.8633 - val_root_mean_squared_error: 40.8517
# Epoch 14/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1620.2772 - root_mean_squared_error: 40.8413 - val_loss: 1614.4061 - val_root_mean_squared_error: 40.8055
# Epoch 15/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1617.3749 - root_mean_squared_error: 40.7951 - val_loss: 1611.9430 - val_root_mean_squared_error: 40.7649
# Epoch 16/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1609.0963 - root_mean_squared_error: 40.7548 - val_loss: 1612.3104 - val_root_mean_squared_error: 40.7292
# Epoch 17/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1621.5937 - root_mean_squared_error: 40.7227 - val_loss: 1611.9122 - val_root_mean_squared_error: 40.6978
# Epoch 18/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1586.3542 - root_mean_squared_error: 40.6858 - val_loss: 1595.9697 - val_root_mean_squared_error: 40.6681
# Epoch 19/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1417.9573 - root_mean_squared_error: 40.6324 - val_loss: 1648.4858 - val_root_mean_squared_error: 40.4575
# Epoch 20/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1430.7633 - root_mean_squared_error: 40.4340 - val_loss: 881.7735 - val_root_mean_squared_error: 40.1230
# Epoch 21/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1413.9865 - root_mean_squared_error: 40.0938 - val_loss: 931.4089 - val_root_mean_squared_error: 39.9455
# Epoch 22/100
# 84/84 [==============================] - 5s 60ms/step - loss: 835.3170 - root_mean_squared_error: 39.8296 - val_loss: 978.4860 - val_root_mean_squared_error: 39.5194
# Epoch 23/100
# 84/84 [==============================] - 5s 60ms/step - loss: 970.1509 - root_mean_squared_error: 39.4306 - val_loss: 1068.6329 - val_root_mean_squared_error: 39.1996
# Epoch 24/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1004.6746 - root_mean_squared_error: 39.1238 - val_loss: 1084.6432 - val_root_mean_squared_error: 38.9156
# Epoch 25/100
# 84/84 [==============================] - 5s 59ms/step - loss: 1497.7479 - root_mean_squared_error: 38.9075 - val_loss: 2224.0854 - val_root_mean_squared_error: 39.0731
# Epoch 26/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1806.8749 - root_mean_squared_error: 39.1129 - val_loss: 1391.2446 - val_root_mean_squared_error: 39.1413
# Epoch 27/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1061.1624 - root_mean_squared_error: 39.0842 - val_loss: 876.4919 - val_root_mean_squared_error: 38.8440
# Epoch 28/100
# 84/84 [==============================] - 5s 60ms/step - loss: 805.3862 - root_mean_squared_error: 38.7571 - val_loss: 915.7866 - val_root_mean_squared_error: 38.5195
# Epoch 29/100
# 84/84 [==============================] - 5s 60ms/step - loss: 839.5444 - root_mean_squared_error: 38.4414 - val_loss: 975.4712 - val_root_mean_squared_error: 38.2435
# Epoch 30/100
# 84/84 [==============================] - 5s 60ms/step - loss: 924.1717 - root_mean_squared_error: 38.1797 - val_loss: 984.4879 - val_root_mean_squared_error: 38.0141
# Epoch 31/100
# 84/84 [==============================] - 5s 60ms/step - loss: 969.3226 - root_mean_squared_error: 37.9593 - val_loss: 1056.1326 - val_root_mean_squared_error: 37.8160
# Epoch 32/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1026.5825 - root_mean_squared_error: 37.7714 - val_loss: 1125.9998 - val_root_mean_squared_error: 37.6501
# Epoch 33/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1056.6474 - root_mean_squared_error: 37.6117 - val_loss: 1095.1715 - val_root_mean_squared_error: 37.5000
# Epoch 34/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1050.1292 - root_mean_squared_error: 37.4626 - val_loss: 1134.9305 - val_root_mean_squared_error: 37.3634
# Epoch 35/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1080.6992 - root_mean_squared_error: 37.3317 - val_loss: 1161.5013 - val_root_mean_squared_error: 37.2453
# Epoch 36/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1105.7944 - root_mean_squared_error: 37.2177 - val_loss: 1166.0736 - val_root_mean_squared_error: 37.1460
# Epoch 37/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1144.8298 - root_mean_squared_error: 37.1234 - val_loss: 1172.3220 - val_root_mean_squared_error: 37.0566
# Epoch 38/100
# 84/84 [==============================] - 5s 59ms/step - loss: 1130.4722 - root_mean_squared_error: 37.0341 - val_loss: 1160.2777 - val_root_mean_squared_error: 36.9697
# Epoch 39/100
# 84/84 [==============================] - 5s 59ms/step - loss: 1162.4276 - root_mean_squared_error: 36.9509 - val_loss: 1177.1633 - val_root_mean_squared_error: 36.8956
# Epoch 40/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1155.9501 - root_mean_squared_error: 36.8771 - val_loss: 1217.3842 - val_root_mean_squared_error: 36.8346
# Epoch 41/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1165.1548 - root_mean_squared_error: 36.8187 - val_loss: 1195.6443 - val_root_mean_squared_error: 36.7728
# Epoch 42/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1131.4197 - root_mean_squared_error: 36.7545 - val_loss: 1167.1176 - val_root_mean_squared_error: 36.7035
# Epoch 43/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1107.6716 - root_mean_squared_error: 36.6838 - val_loss: 1195.4196 - val_root_mean_squared_error: 36.6369
# Epoch 44/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1154.0878 - root_mean_squared_error: 36.6222 - val_loss: 1177.4113 - val_root_mean_squared_error: 36.5719
# Epoch 45/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1161.8209 - root_mean_squared_error: 36.5580 - val_loss: 1225.5277 - val_root_mean_squared_error: 36.5229
# Epoch 46/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1197.3981 - root_mean_squared_error: 36.5131 - val_loss: 1218.3462 - val_root_mean_squared_error: 36.4801
# Epoch 47/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1202.5780 - root_mean_squared_error: 36.4706 - val_loss: 1236.9038 - val_root_mean_squared_error: 36.4458
# Epoch 48/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1215.1856 - root_mean_squared_error: 36.4374 - val_loss: 1258.4049 - val_root_mean_squared_error: 36.4198
# Epoch 49/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1246.6816 - root_mean_squared_error: 36.4144 - val_loss: 1246.4916 - val_root_mean_squared_error: 36.3965
# Epoch 50/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1241.0387 - root_mean_squared_error: 36.3909 - val_loss: 1281.9686 - val_root_mean_squared_error: 36.3727
# Epoch 51/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1275.3848 - root_mean_squared_error: 36.3697 - val_loss: 1276.2706 - val_root_mean_squared_error: 36.3562
# Epoch 52/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1255.0521 - root_mean_squared_error: 36.3518 - val_loss: 1269.6886 - val_root_mean_squared_error: 36.3426
# Epoch 53/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1325.6883 - root_mean_squared_error: 36.3416 - val_loss: 1292.4170 - val_root_mean_squared_error: 36.3790
# Epoch 54/100
# 84/84 [==============================] - 5s 60ms/step - loss: 1003.8028 - root_mean_squared_error: 36.3596 - val_loss: 850.2569 - val_root_mean_squared_error: 36.2677
# Epoch 55/100
# 84/84 [==============================] - 5s 60ms/step - loss: 893.0514 - root_mean_squared_error: 36.2379 - val_loss: 1136.0864 - val_root_mean_squared_error: 36.1873
# Epoch 56/100
# 84/84 [==============================] - 5s 60ms/step - loss: 832.4195 - root_mean_squared_error: 36.1581 - val_loss: 561.7956 - val_root_mean_squared_error: 36.0412
# Epoch 57/100
# 84/84 [==============================] - 5s 60ms/step - loss: 565.9682 - root_mean_squared_error: 35.9932 - val_loss: 474.2466 - val_root_mean_squared_error: 35.8604
# Epoch 58/100
# 84/84 [==============================] - 5s 60ms/step - loss: 553.1139 - root_mean_squared_error: 35.8120 - val_loss: 526.1663 - val_root_mean_squared_error: 35.6990
# Epoch 59/100
# 84/84 [==============================] - 5s 60ms/step - loss: 515.2644 - root_mean_squared_error: 35.6507 - val_loss: 545.3669 - val_root_mean_squared_error: 35.5113
# Epoch 60/100
# 84/84 [==============================] - 5s 60ms/step - loss: 573.9585 - root_mean_squared_error: 35.4678 - val_loss: 469.5519 - val_root_mean_squared_error: 35.3442
# Epoch 61/100
# 84/84 [==============================] - 5s 60ms/step - loss: 485.4061 - root_mean_squared_error: 35.2964 - val_loss: 403.8588 - val_root_mean_squared_error: 35.1605
# Epoch 62/100
# 84/84 [==============================] - 5s 60ms/step - loss: 396.6137 - root_mean_squared_error: 35.1088 - val_loss: 342.2965 - val_root_mean_squared_error: 34.9615
# Epoch 63/100
# 84/84 [==============================] - 5s 60ms/step - loss: 311.0626 - root_mean_squared_error: 34.9058 - val_loss: 310.2640 - val_root_mean_squared_error: 34.7528
# Epoch 64/100
# 84/84 [==============================] - 5s 59ms/step - loss: 294.2185 - root_mean_squared_error: 34.6974 - val_loss: 339.8036 - val_root_mean_squared_error: 34.5480
# Epoch 65/100
# 84/84 [==============================] - 5s 59ms/step - loss: 285.8499 - root_mean_squared_error: 34.4937 - val_loss: 248.3299 - val_root_mean_squared_error: 34.3435
# Epoch 66/100
# 84/84 [==============================] - 5s 60ms/step - loss: 376.4295 - root_mean_squared_error: 34.2956 - val_loss: 298.8804 - val_root_mean_squared_error: 34.1616
# Epoch 67/100
# 84/84 [==============================] - 5s 60ms/step - loss: 341.3922 - root_mean_squared_error: 34.1128 - val_loss: 278.9117 - val_root_mean_squared_error: 33.9777
# Epoch 68/100
# 84/84 [==============================] - 5s 60ms/step - loss: 299.4233 - root_mean_squared_error: 33.9277 - val_loss: 284.8143 - val_root_mean_squared_error: 33.7910
# Epoch 69/100
# 84/84 [==============================] - 5s 61ms/step - loss: 298.9383 - root_mean_squared_error: 33.7419 - val_loss: 289.3999 - val_root_mean_squared_error: 33.6093
# Epoch 70/100
# 84/84 [==============================] - 5s 60ms/step - loss: 307.2384 - root_mean_squared_error: 33.5621 - val_loss: 314.6587 - val_root_mean_squared_error: 33.4360
# Epoch 71/100
# 84/84 [==============================] - 5s 60ms/step - loss: 308.2421 - root_mean_squared_error: 33.3899 - val_loss: 195.2696 - val_root_mean_squared_error: 33.2618
# Epoch 72/100
# 84/84 [==============================] - 5s 61ms/step - loss: 377.8719 - root_mean_squared_error: 33.2196 - val_loss: 336.5341 - val_root_mean_squared_error: 33.1211
# Epoch 73/100
# 84/84 [==============================] - 5s 60ms/step - loss: 343.9177 - root_mean_squared_error: 33.0792 - val_loss: 252.1850 - val_root_mean_squared_error: 32.9597
# Epoch 74/100
# 84/84 [==============================] - 5s 60ms/step - loss: 259.6806 - root_mean_squared_error: 32.9138 - val_loss: 214.0467 - val_root_mean_squared_error: 32.7862
# Epoch 75/100
# 84/84 [==============================] - 5s 60ms/step - loss: 221.7483 - root_mean_squared_error: 32.7393 - val_loss: 181.7550 - val_root_mean_squared_error: 32.6115
# Epoch 76/100
# 84/84 [==============================] - 5s 60ms/step - loss: 214.4085 - root_mean_squared_error: 32.5650 - val_loss: 200.8201 - val_root_mean_squared_error: 32.4385
# Epoch 77/100
# 84/84 [==============================] - 5s 60ms/step - loss: 202.5063 - root_mean_squared_error: 32.3925 - val_loss: 194.3403 - val_root_mean_squared_error: 32.2673
# Epoch 78/100
# 84/84 [==============================] - 5s 60ms/step - loss: 194.5990 - root_mean_squared_error: 32.2218 - val_loss: 208.2236 - val_root_mean_squared_error: 32.0985
# Epoch 79/100
# 84/84 [==============================] - 5s 61ms/step - loss: 185.1744 - root_mean_squared_error: 32.0536 - val_loss: 165.4500 - val_root_mean_squared_error: 31.9312
# Epoch 80/100
# 84/84 [==============================] - 5s 61ms/step - loss: 185.1784 - root_mean_squared_error: 31.8870 - val_loss: 173.1503 - val_root_mean_squared_error: 31.7671
# Epoch 81/100
# 84/84 [==============================] - 5s 61ms/step - loss: 196.9716 - root_mean_squared_error: 31.7244 - val_loss: 193.9853 - val_root_mean_squared_error: 31.6098
# Epoch 82/100
# 84/84 [==============================] - 5s 62ms/step - loss: 191.2439 - root_mean_squared_error: 31.5676 - val_loss: 164.7688 - val_root_mean_squared_error: 31.4511
# Epoch 83/100
# 84/84 [==============================] - 5s 61ms/step - loss: 177.7086 - root_mean_squared_error: 31.4091 - val_loss: 204.7921 - val_root_mean_squared_error: 31.2949
# Epoch 84/100
# 84/84 [==============================] - 5s 60ms/step - loss: 175.6176 - root_mean_squared_error: 31.2535 - val_loss: 205.1478 - val_root_mean_squared_error: 31.1412
# Epoch 85/100
# 84/84 [==============================] - 5s 60ms/step - loss: 179.8924 - root_mean_squared_error: 31.1011 - val_loss: 164.1061 - val_root_mean_squared_error: 30.9901
# Epoch 86/100
# 84/84 [==============================] - 5s 61ms/step - loss: 169.2637 - root_mean_squared_error: 30.9500 - val_loss: 172.9024 - val_root_mean_squared_error: 30.8416
# Epoch 87/100
# 84/84 [==============================] - 5s 61ms/step - loss: 192.1463 - root_mean_squared_error: 30.8034 - val_loss: 172.1403 - val_root_mean_squared_error: 30.6992
# Epoch 88/100
# 84/84 [==============================] - 5s 61ms/step - loss: 171.3964 - root_mean_squared_error: 30.6606 - val_loss: 163.6797 - val_root_mean_squared_error: 30.5555
# Epoch 89/100
# 84/84 [==============================] - 5s 61ms/step - loss: 166.6679 - root_mean_squared_error: 30.5173 - val_loss: 173.1662 - val_root_mean_squared_error: 30.4142
# Epoch 90/100
# 84/84 [==============================] - 5s 61ms/step - loss: 162.5890 - root_mean_squared_error: 30.3765 - val_loss: 163.3325 - val_root_mean_squared_error: 30.2742
# Epoch 91/100
# 84/84 [==============================] - 5s 60ms/step - loss: 159.8382 - root_mean_squared_error: 30.2371 - val_loss: 156.5989 - val_root_mean_squared_error: 30.1368
# Epoch 92/100
# 84/84 [==============================] - 5s 60ms/step - loss: 157.1154 - root_mean_squared_error: 30.1001 - val_loss: 176.6999 - val_root_mean_squared_error: 30.0013
# Epoch 93/100
# 84/84 [==============================] - 5s 60ms/step - loss: 155.2461 - root_mean_squared_error: 29.9652 - val_loss: 167.7565 - val_root_mean_squared_error: 29.8676
# Epoch 94/100
# 84/84 [==============================] - 5s 62ms/step - loss: 154.0985 - root_mean_squared_error: 29.8321 - val_loss: 174.3107 - val_root_mean_squared_error: 29.7363
# Epoch 95/100
# 84/84 [==============================] - 5s 61ms/step - loss: 159.6744 - root_mean_squared_error: 29.7017 - val_loss: 174.1818 - val_root_mean_squared_error: 29.6076
# Epoch 96/100
# 84/84 [==============================] - 5s 60ms/step - loss: 154.5857 - root_mean_squared_error: 29.5733 - val_loss: 170.2223 - val_root_mean_squared_error: 29.4803
# Epoch 97/100
# 84/84 [==============================] - 5s 61ms/step - loss: 153.6188 - root_mean_squared_error: 29.4465 - val_loss: 165.5088 - val_root_mean_squared_error: 29.3552
# Epoch 98/100
# 84/84 [==============================] - 5s 61ms/step - loss: 150.4682 - root_mean_squared_error: 29.3219 - val_loss: 162.0506 - val_root_mean_squared_error: 29.2315
# Epoch 99/100
# 84/84 [==============================] - 5s 61ms/step - loss: 149.4345 - root_mean_squared_error: 29.1986 - val_loss: 174.5630 - val_root_mean_squared_error: 29.1096
# Epoch 100/100
# 84/84 [==============================] - 5s 61ms/step - loss: 151.2155 - root_mean_squared_error: 29.0773 - val_loss: 160.7726 - val_root_mean_squared_error: 28.9897
# 14.512619122165487
# [[109.78829  ]
#  [116.64857  ]
#  [ 43.81347  ]
#  [ 86.44148  ]
#  [102.49389  ]
#  [106.82919  ]
#  [108.751915 ]
#  [ 91.59988  ]
#  [116.26808  ]
#  [ 86.50235  ]
#  [ 93.431755 ]
#  [101.15578  ]
#  [ 77.77433  ]
#  [108.26135  ]
#  [102.92344  ]
#  [ 95.21398  ]
#  [ 47.555946 ]
#  [ 25.869577 ]
#  [ 96.816376 ]
#  [ 18.086988 ]
#  [ 60.991333 ]
#  [117.9995   ]
#  [116.6479   ]
#  [ 12.663578 ]
#  [115.0289   ]
#  [115.980446 ]
#  [ 87.03922  ]
#  [103.303505 ]
#  [ 97.81119  ]
#  [108.95722  ]
#  [  7.511939 ]
#  [ 40.03804  ]
#  [110.39051  ]
#  [  5.586898 ]
#  [  6.1602335]
#  [ 23.162468 ]
#  [ 24.738134 ]
#  [ 52.90565  ]
#  [118.16187  ]
#  [ 33.742844 ]
#  [ 20.15693  ]
#  [ 13.287884 ]
#  [ 54.739746 ]
#  [ 94.632286 ]
#  [ 78.93928  ]
#  [ 36.832165 ]
#  [112.02367  ]
#  [107.33454  ]
#  [ 16.79644  ]
#  [104.34816  ]
#  [105.824394 ]
#  [ 24.374918 ]
#  [ 22.895452 ]
#  [117.28831  ]
#  [117.39846  ]
#  [ 12.74281  ]
#  [105.190575 ]
#  [ 44.98932  ]
#  [110.863144 ]
#  [106.95485  ]
#  [ 17.668709 ]
#  [ 38.23675  ]
#  [ 89.0469   ]
#  [ 20.656904 ]
#  [118.2959   ]
#  [ 16.909666 ]
#  [117.72802  ]
#  [  7.2626843]
#  [117.83985  ]
#  [ 85.838234 ]
#  [111.21873  ]
#  [ 57.464386 ]
#  [102.44875  ]
#  [105.68589  ]
#  [102.49387  ]
#  [  6.3475957]
#  [ 25.605375 ]
#  [118.767395 ]
#  [ 94.891945 ]
#  [ 94.5774   ]
#  [  7.636613 ]
#  [ 11.24977  ]
#  [118.38548  ]
#  [ 84.602264 ]
#  [117.24161  ]
#  [109.7759   ]
#  [117.1387   ]
#  [114.362404 ]
#  [110.60295  ]
#  [ 29.792469 ]
#  [ 24.41465  ]
#  [ 25.01198  ]
#  [ 45.486862 ]
#  [ 74.235504 ]
#  [ 99.233284 ]
#  [104.65454  ]
#  [ 88.520775 ]
#  [ 62.00797  ]
#  [117.39028  ]
#  [ 11.115724 ]]
# 210.61611378504335
